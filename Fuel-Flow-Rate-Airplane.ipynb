# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn import model_selection, preprocessing
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
import sys
import seaborn as sns
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from keras.layers import LeakyReLU
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
# %matplotlib inline

# %%
def remove_variable_with_0_variance(df):
    key_list = df.keys()
    var_list = []
    name_list = []
    for key in key_list:
        var_list.append(df[key].var())
        name_list.append(key)
        if df[key].var() == 0:
            df = df.drop(columns = key)
    return df

# %%
def remove_min_max(df):
    m = 0
    list_of_att = []
    for key in df.keys():
        if key[:-4]+'Min' in df.keys():
            list_of_att.append(key)
    for att in list_of_att:
        df = df.drop(columns = [att[:-4]+'Min',att[:-4]+'Max'])
    return df

# %%
def plot_variances_of_min_max(df):
    m = 0
    list_of_att = []
    for key in df.keys():
        if key[:-4]+'Min' in df.keys():
            list_of_att.append(key)
            list_of_att.append(key[:-4]+'Min')
            list_of_att.append(key[:-4]+'Max')
    plt.figure(figsize=(20,20))
    data = df.loc[:,list_of_att]
    corr = data.corr()
    ax = sns.heatmap(
    corr
)

# %%
def normalize_data(df):
    normalized_df=(df-df.mean())/df.std()
    return normalized_df

# %%
def calc_acc_and_rmse(predictions,test_target):
    acc_2 = 0
    acc_5 = 0
    total = 0
    error = 0
    for i in range(len(predictions)):
        error+=(predictions[i]-test_target[i])**2
        if abs((predictions[i]-test_target[i])/(test_target[i]+1))<0.02:
            acc_2 += 1
        total += 1
        if abs((predictions[i]-test_target[i])/(test_target[i]+1))<0.05:
            acc_5 += 1
    error = error/len(predictions)
    error**0.5
    print('acc_with_2%: '+str(acc_2/total),'acc_with_5%: '+str(acc_5/total),'RMSE: '+str(error**0.5))
    return acc_2/total,error**0.5

# %%
def normalize_and_split_data_from_data_frame_randomly(df,ratio):
    msk = np.random.rand(len(df)) < ratio
    target = df['FF']
    df = normalize_data(df)
    train = df.drop(columns ='FF')
    train_data = train[msk]
    test_data = train[~msk]
    train_target = target[msk].to_numpy()
    test_target = target[~msk].to_numpy()
    return train_data,test_data,train_target,test_target

# %%
def normalize_and_split_data_from_data_frame(df,number_of_samples_in_train):
    target = df['FF']
    df = normalize_data(df)
    no = number_of_samples_in_train
    train = df.drop(columns ='FF')
    train_data = train[:no]
    test_data = train[no:]
    train_target = target[:no].to_numpy()
    test_target = target[no:].to_numpy()
    return train_data,test_data,train_target,test_target

# %%
def ensemble(list_of_models,test_data):
    list_of_predictions=[]
    for model in list_of_models:
        list_of_predictions.append(model.predict(test_data))
    final_prediction =np.sum(list_of_predictions,axis=0)
    return final_prediction/len(list_of_models)

# %%
def make_net(train,height,width):
    NN_model = Sequential()
    NN_model.add(Dense(width, kernel_initializer='normal',input_dim = train.shape[1], activation='relu'))
    for i in range(height - 1):
        NN_model.add(Dense(width, kernel_initializer='normal',activation='relu'))
        
    NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))
    NN_model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])
    NN_model.summary()
    return NN_model

# %% [markdown]
# # We first do an analysis of how the min-max versions of attributes are correlated and if they are we remove the min-max versions and keep only the means.

# %%
df =  pd.read_pickle('PH_data_one.df')
df = df.drop(columns = ['Flight_instance_ID','ACID'])
plot_variances_of_min_max(df)

# %% [markdown]
# # Next we inspect which kind of split is best for training and validation,random or deterministic

# %%
#Code for deterministic split using flight order
df =  pd.read_pickle('PH_data_one.df')
df = df.drop(columns = ['Flight_instance_ID','ACID'])
df = remove_variable_with_0_variance(df)
df = remove_min_max(df)
train_data,test_data,train_target,test_target = normalize_and_split_data_from_data_frame(df,80000)

# %%
iowa_model = DecisionTreeRegressor(random_state=1)
rf_model = RandomForestRegressor(random_state=1)

# %%
iowa_model.fit(train_data, train_target)
predictions = iowa_model.predict(test_data)
calc_acc_and_rmse(predictions,test_target)
# Out:
# acc_with_2%: 0.468263266712612 acc_with_5%: 0.6891798759476223 RMSE: 735.3773518547815
# (0.468263266712612, 735.3773518547815)

# %%
#Code for random split
df =  pd.read_pickle('PH_data_one.df')
df = df.drop(columns = ['Flight_instance_ID','ACID'])
df = remove_variable_with_0_variance(df)
df = remove_min_max(df)
train_data,test_data,train_target,test_target = normalize_and_split_data_from_data_frame_randomly(df,0.8)

# %%
iowa_model = DecisionTreeRegressor(random_state=1)
rf_model = RandomForestRegressor(random_state=1)

# %%
iowa_model.fit(train_data, train_target)
predictions = iowa_model.predict(test_data)
calc_acc_and_rmse(predictions,test_target)
# Out:
# acc_with_2%: 0.8989072287504001 acc_with_5%: 0.9485163001234511 RMSE: 164.05658818228426
# (0.8989072287504001, 164.05658818228426)

# %%
importance_list = list(zip(train_data.columns, iowa_model.feature_importances_))
#print(importance_list)
new_list = (sorted(importance_list,key=lambda x: x[1]))
from math import log
testList2 = [(elem1, log(elem2)) for elem1, elem2 in new_list if elem2!=0]

# %%
plt.figure(figsize=(70,20))
plt.scatter(*zip(*testList2))
plt.show()

# %% [markdown]
# # The Random Forest Regressor giving higher accuracy was expected

# %%
rf_model.fit(train_data, train_target)
predictions = rf_model.predict(test_data)
calc_acc_and_rmse(predictions,test_target)
# Out:
# acc_with_2%: 0.4986905582356995 acc_with_5%: 0.7169882839421089 RMSE: 669.1222819329723
# (0.4986905582356995, 669.1222819329723)

# %% [markdown]
# # Now we try to combine two random forest models

# %%
#Trying to use random ensemble of two random forest classifier
rf_model_2 = RandomForestRegressor(random_state=0)
rf_model_2.fit(train_data, train_target)
predictions = ensemble([rf_model_2,rf_model],test_data)
calc_acc_and_rmse(predictions,test_target)
# Out:
# acc_with_2%: 0.4966919365954514 acc_with_5%: 0.7569951757408684 RMSE: 639.6527977229019
# (0.4966919365954514, 639.6527977229019)

# %%
rf_model_3 = RandomForestRegressor(random_state=3)
rf_model_3.fit(train_data, train_target)
predictions = ensemble([rf_model_2,rf_model,rf_model_3],test_data)
calc_acc_and_rmse(predictions,test_target)
# Out:
# acc_with_2%: 0.4912818745692626 acc_with_5%: 0.721605789110958 RMSE: 636.0509549680163
# (0.4912818745692626, 636.0509549680163)

# %%
X_train, X_test, y_train, y_test = normalize_and_split_data_from_data_frame(df[0:80000],64000)

# %%
model = xgb.XGBRegressor()
model.fit(train_data,train_target)
# Out:
# [13:27:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=1, gamma=0,
#        importance_type='gain', learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=None, subsample=1, verbosity=1)

# %%
predictions = model.predict(test_data)
calc_acc_and_rmse(predictions,test_target)
# Out:
# acc_with_2%: 0.3034803583735355 acc_with_5%: 0.5677463818056513 RMSE: 554.6744797359878
# (0.3034803583735355, 554.6744797359878)

# %% [markdown]
# # We see that XGBoost give inferior performance and hence do hyperparameter tuning.

# %%
model3 = xgb.XGBRegressor(max_depth=8,min_child_weight=4,random_state=1)
model3.fit(train_data,train_target)
# Out:
# [11:28:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=1, gamma=0,
#        importance_type='gain', learning_rate=0.1, max_delta_step=0,
#        max_depth=8, min_child_weight=4, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=1,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=None, subsample=1, verbosity=1)

# %%
predictions = model3.predict(data=test_data)
calc_acc_and_rmse(predictions,test_target)
# Out:
# acc_with_2%: 0.50723638869745 acc_with_5%: 0.7628876636802205 RMSE: 595.9574203063295
# (0.50723638869745, 595.9574203063295)

# %%
predictions = iowa_model.predict(test_data)
calc_acc_and_rmse(predictions,test_target)
# Out:
# acc_with_2%: 0.468263266712612 acc_with_5%: 0.6891798759476223 RMSE: 735.3773518547815
# (0.468263266712612, 735.3773518547815)

# %% [markdown]
# # The ensemble of decision-tree and XGBoost is very nice

# %%
predictions = np.sum([model3.predict(data=test_data),iowa_model.predict(test_data)],axis = 0)/2
calc_acc_and_rmse(predictions,test_target)
# Out:
# acc_with_2%: 0.5574776016540317 acc_with_5%: 0.778394210889042 RMSE: 612.1570689614778
# (0.5574776016540317, 612.1570689614778)

# %% [markdown]
# # For optimization of XGBOOST we do GRID SEARCH

# %%
#Remember to change
gridsearch_params = [
    (max_depth, min_child_weight)
    for max_depth in range(4,10)
    for min_child_weight in range(4,10)
]

min_rmse = float("Inf")
best_params = None
for max_depth, min_child_weight in gridsearch_params:
    print("CV with max_depth={}, min_child_weight={}".format(
                             max_depth,
                             min_child_weight))

    # Update our parameters
    model = xgb.XGBRegressor(max_depth=max_depth,min_child_weight=min_child_weight)
    #print(dtest.num_row())
    model.fit(X_train,y_train)
    #print(len(prediction))
    prediction = model.predict(data = X_test)
    _,rmse = calc_acc_and_rmse(prediction,y_test)
    if rmse<min_rmse:
        min_rmse = rmse
        best_params = (max_depth,min_child_weight)
# Out:
# CV with max_depth=4, min_child_weight=4
# [10:58:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.363375 acc_with_5%: 0.5939375 RMSE: 345.3298043412693
# CV with max_depth=4, min_child_weight=5
# [10:58:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.3636875 acc_with_5%: 0.5869375 RMSE: 344.3159024276028
# CV with max_depth=4, min_child_weight=6
# [10:59:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.3619375 acc_with_5%: 0.5844375 RMSE: 345.99501477632464
# CV with max_depth=4, min_child_weight=7
# [10:59:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.36125 acc_with_5%: 0.588375 RMSE: 340.6632603267989
# CV with max_depth=4, min_child_weight=8
# [10:59:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.3678125 acc_with_5%: 0.5980625 RMSE: 338.24676575023256
# CV with max_depth=4, min_child_weight=9
# [11:00:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.3798125 acc_with_5%: 0.596875 RMSE: 337.1711470622706
# CV with max_depth=5, min_child_weight=4
# [11:00:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.3998125 acc_with_5%: 0.634375 RMSE: 309.0358473399905
# CV with max_depth=5, min_child_weight=5
# [11:01:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.4139375 acc_with_5%: 0.6479375 RMSE: 306.54250162063596
# CV with max_depth=5, min_child_weight=6
# [11:01:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.4113125 acc_with_5%: 0.639625 RMSE: 305.28414092318627
# CV with max_depth=5, min_child_weight=7
# [11:02:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.397125 acc_with_5%: 0.6288125 RMSE: 304.448283142261
# CV with max_depth=5, min_child_weight=8
# [11:02:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.4085 acc_with_5%: 0.6293125 RMSE: 303.95244965064467
# CV with max_depth=5, min_child_weight=9
# [11:03:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.39875 acc_with_5%: 0.6319375 RMSE: 307.0711943733859
# CV with max_depth=6, min_child_weight=4
# [11:03:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.4619375 acc_with_5%: 0.688125 RMSE: 284.6565025858779
# CV with max_depth=6, min_child_weight=5
# [11:04:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.456 acc_with_5%: 0.6755 RMSE: 286.18974723022023
# CV with max_depth=6, min_child_weight=6
# [11:04:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.45025 acc_with_5%: 0.6659375 RMSE: 283.86635049719666
# CV with max_depth=6, min_child_weight=7
# [11:05:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.4325 acc_with_5%: 0.667375 RMSE: 285.0888583111736
# CV with max_depth=6, min_child_weight=8
# [11:06:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.438 acc_with_5%: 0.668375 RMSE: 285.3194371349096
# CV with max_depth=6, min_child_weight=9
# [11:06:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.455875 acc_with_5%: 0.67975 RMSE: 285.4266947334387
# CV with max_depth=7, min_child_weight=4
# [11:07:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.4803125 acc_with_5%: 0.7055 RMSE: 284.7813241511252
# CV with max_depth=7, min_child_weight=5
# [11:07:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.49925 acc_with_5%: 0.7074375 RMSE: 280.4179225410263
# CV with max_depth=7, min_child_weight=6
# [11:08:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.4879375 acc_with_5%: 0.7091875 RMSE: 281.30523520800915
# CV with max_depth=7, min_child_weight=7
# [11:09:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.493 acc_with_5%: 0.6996875 RMSE: 282.7615277714062
# CV with max_depth=7, min_child_weight=8
# [11:10:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.4670625 acc_with_5%: 0.6935 RMSE: 281.87907760424133
# CV with max_depth=7, min_child_weight=9
# [11:10:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.4903125 acc_with_5%: 0.6939375 RMSE: 279.20645996443335
# CV with max_depth=8, min_child_weight=4
# [11:11:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.489625 acc_with_5%: 0.6925625 RMSE: 292.55093865924755
# CV with max_depth=8, min_child_weight=5
# [11:12:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.4975625 acc_with_5%: 0.6953125 RMSE: 286.8011892510682
# CV with max_depth=8, min_child_weight=6
# [11:13:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.492125 acc_with_5%: 0.69425 RMSE: 286.4551019510114
# CV with max_depth=8, min_child_weight=7
# [11:13:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.4751875 acc_with_5%: 0.7024375 RMSE: 287.882630691744
# CV with max_depth=8, min_child_weight=8
# [11:14:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.4929375 acc_with_5%: 0.684625 RMSE: 290.15491388293634
# CV with max_depth=8, min_child_weight=9
# [11:15:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.4765 acc_with_5%: 0.6700625 RMSE: 288.2006033032857
# CV with max_depth=9, min_child_weight=4
# [11:16:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.480375 acc_with_5%: 0.6945625 RMSE: 302.6791052663753
# CV with max_depth=9, min_child_weight=5
# [11:17:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.4778125 acc_with_5%: 0.67825 RMSE: 313.1148398009603
# CV with max_depth=9, min_child_weight=6
# [11:18:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.496125 acc_with_5%: 0.6743125 RMSE: 308.13366360952136
# CV with max_depth=9, min_child_weight=7
# [11:19:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.4749375 acc_with_5%: 0.6675625 RMSE: 305.81567750065216
# CV with max_depth=9, min_child_weight=8
# [11:20:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.4859375 acc_with_5%: 0.6664375 RMSE: 333.4404390164971
# CV with max_depth=9, min_child_weight=9
# [11:21:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# acc_with_2%: 0.4939375 acc_with_5%: 0.679125 RMSE: 306.14227124861816

# %%
print(best_params)
# Out:
# (7, 9)

# %%
gridsearch_params = [
    (subsample, colsample)
    for subsample in [i/10. for i in range(7,11)]
    for colsample in [i/10. for i in range(7,11)]
]
min_rmse = float("Inf")
best_params = None
for subsample, colsample in reversed(gridsearch_params):
    model = xgb.XGBRegressor(subsample = subsample,colsample_bynode=colsample,max_depth=7 ,min_child_weight=9 )
    model.fit(X_train,y_train)
    prediction = model.predict(data = X_test)
    if rmse<min_rmse:
        min_rmse = rmse
        best_params = (subsample, colsample)
    params['subsample'] = subsample
    params['colsample_bytree'] = colsample
# Out:
# [11:34:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:34:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:35:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:36:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:36:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:37:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:38:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:38:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:39:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:39:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:40:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:41:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:41:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:42:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:43:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:44:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
print(best_params
     )
# Out:
# (1.0, 1.0)

# %% [markdown]
# # NEURAL NETWORK

# %%
def best_net_finder(list_of_width,list_of_height):
    for width in list_of_width:
        for height in list_of_height:
            NN_model = make_net(height,width)
            for epoch in range(3):
                NN_model.fit(train, train_target, epochs=1, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
                error = 0
                total = 0
                acc_2 = 0
                acc_5 = 0
                predictions = NN_model.predict(test)
                for i in range(len(predictions)):
                    error+=(predictions[i]-test_target[i])**2
                    if abs((predictions[i]-test_target[i])/(test_target[i]))<0.02:
                        acc_2 += 1
                    total += 1
                    if abs((predictions[i]-test_target[i])/(test_target[i]))<0.05:
                        acc_5 += 1
                error = error/len(predictions)
                error**0.5

                print(acc_2,acc_5,total,acc_2/total,acc_5/total,error**0.5,height,width,epoch)

# %%
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %%
model_list = []
acc_list = []
for i in range(10):
    new_model = make_net(X_train,6,256)
    new_model.fit(train_data[0:64000], train_target[0:64000], epochs=4, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
    predictions = new_model.predict(train_data[64000:])
    acc_list.append(calc_acc_and_rmse(predictions,train_target[64000:]))
    model_list.append(new_model)
    print(calc_acc_and_rmse(predictions,train_target[64000:]))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_400 (Dense)            (None, 256)               27648
# _________________________________________________________________
# dense_401 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_402 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_403 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_404 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_405 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_406 (Dense)            (None, 1)                 257
# =================================================================
# Total params: 356,865
# Trainable params: 356,865
# Non-trainable params: 0
# _________________________________________________________________
# Train on 51200 samples, validate on 12800 samples
# Epoch 1/4
# 51200/51200 [==============================] - 19s 366us/step - loss: 1050276.8638 - mean_absolute_error: 464.5618 - val_loss: 702932.0765 - val_mean_absolute_error: 666.8866
#
# Epoch 00001: val_loss improved from inf to 702932.07655, saving model to Weights-001--702932.07655.hdf5
# Epoch 2/4
# 51200/51200 [==============================] - 14s 269us/step - loss: 120108.0165 - mean_absolute_error: 241.7331 - val_loss: 824494.0744 - val_mean_absolute_error: 736.9524
#
# Epoch 00002: val_loss did not improve from 702932.07655
# Epoch 3/4
# 51200/51200 [==============================] - 14s 267us/step - loss: 95415.1353 - mean_absolute_error: 213.4193 - val_loss: 867753.6195 - val_mean_absolute_error: 747.9789
#
# Epoch 00003: val_loss did not improve from 702932.07655
# Epoch 4/4
# 51200/51200 [==============================] - 14s 270us/step - loss: 97485.9681 - mean_absolute_error: 205.7450 - val_loss: 815048.0832 - val_mean_absolute_error: 747.1453
#
# Epoch 00004: val_loss did not improve from 702932.07655
# acc_with_2%: 0.1736875 acc_with_5%: 0.4209375 RMSE: [494.1301]
# acc_with_2%: 0.1736875 acc_with_5%: 0.4209375 RMSE: [494.1301]
# (0.1736875, array([494.1301], dtype=float32))
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_407 (Dense)            (None, 256)               27648
# _________________________________________________________________
# dense_408 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_409 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_410 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_411 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_412 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_413 (Dense)            (None, 1)                 257
# =================================================================
# Total params: 356,865
# Trainable params: 356,865
# Non-trainable params: 0
# _________________________________________________________________
# Train on 51200 samples, validate on 12800 samples
# Epoch 1/4
# 51200/51200 [==============================] - 18s 359us/step - loss: 1110030.5891 - mean_absolute_error: 469.7997 - val_loss: 930432.5127 - val_mean_absolute_error: 772.5470
#
# Epoch 00001: val_loss did not improve from 702932.07655
# Epoch 2/4
# 51200/51200 [==============================] - 15s 284us/step - loss: 113534.3501 - mean_absolute_error: 234.7275 - val_loss: 886916.4078 - val_mean_absolute_error: 785.6283
#
# Epoch 00002: val_loss did not improve from 702932.07655
# Epoch 3/4
# 51200/51200 [==============================] - 14s 277us/step - loss: 99835.7986 - mean_absolute_error: 219.3520 - val_loss: 884566.9285 - val_mean_absolute_error: 800.4663
#
# Epoch 00003: val_loss did not improve from 702932.07655
# Epoch 4/4
# 51200/51200 [==============================] - 14s 273us/step - loss: 90187.8221 - mean_absolute_error: 207.7855 - val_loss: 1029494.2812 - val_mean_absolute_error: 860.8638
#
# Epoch 00004: val_loss did not improve from 702932.07655
# acc_with_2%: 0.1754375 acc_with_5%: 0.4499375 RMSE: [482.23907]
# acc_with_2%: 0.1754375 acc_with_5%: 0.4499375 RMSE: [482.23907]
# (0.1754375, array([482.23907], dtype=float32))
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_414 (Dense)            (None, 256)               27648
# _________________________________________________________________
# dense_415 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_416 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_417 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_418 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_419 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_420 (Dense)            (None, 1)                 257
# =================================================================
# Total params: 356,865
# Trainable params: 356,865
# Non-trainable params: 0
# _________________________________________________________________
# Train on 51200 samples, validate on 12800 samples
# Epoch 1/4
# 51200/51200 [==============================] - 19s 363us/step - loss: 1160087.7858 - mean_absolute_error: 477.0079 - val_loss: 807872.4256 - val_mean_absolute_error: 739.8273
#
# Epoch 00001: val_loss did not improve from 702932.07655
# Epoch 2/4
# 51200/51200 [==============================] - 14s 283us/step - loss: 112260.7386 - mean_absolute_error: 232.5126 - val_loss: 825263.1523 - val_mean_absolute_error: 745.9667
#
# Epoch 00002: val_loss did not improve from 702932.07655
# Epoch 3/4
# 51200/51200 [==============================] - 14s 275us/step - loss: 97067.2141 - mean_absolute_error: 215.4805 - val_loss: 839336.8708 - val_mean_absolute_error: 748.1959
#
# Epoch 00003: val_loss did not improve from 702932.07655
# Epoch 4/4
# 51200/51200 [==============================] - 14s 277us/step - loss: 86534.5957 - mean_absolute_error: 201.1791 - val_loss: 792278.0712 - val_mean_absolute_error: 736.4664
#
# Epoch 00004: val_loss did not improve from 702932.07655
# acc_with_2%: 0.112875 acc_with_5%: 0.3245625 RMSE: [524.5391]
# acc_with_2%: 0.112875 acc_with_5%: 0.3245625 RMSE: [524.5391]
# (0.112875, array([524.5391], dtype=float32))
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_421 (Dense)            (None, 256)               27648
# _________________________________________________________________
# dense_422 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_423 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_424 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_425 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_426 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_427 (Dense)            (None, 1)                 257
# =================================================================
# Total params: 356,865
# Trainable params: 356,865
# Non-trainable params: 0
# _________________________________________________________________
# Train on 51200 samples, validate on 12800 samples
# Epoch 1/4
# 51200/51200 [==============================] - 19s 373us/step - loss: 1125218.2463 - mean_absolute_error: 470.6278 - val_loss: 968903.3692 - val_mean_absolute_error: 782.9233
#
# Epoch 00001: val_loss did not improve from 702932.07655
# Epoch 2/4
# 51200/51200 [==============================] - 14s 280us/step - loss: 116449.7170 - mean_absolute_error: 237.8001 - val_loss: 850670.2083 - val_mean_absolute_error: 753.3420
#
# Epoch 00002: val_loss did not improve from 702932.07655
# Epoch 3/4
# 51200/51200 [==============================] - 14s 280us/step - loss: 95251.2192 - mean_absolute_error: 215.1052 - val_loss: 833242.7519 - val_mean_absolute_error: 733.4033
#
# Epoch 00003: val_loss did not improve from 702932.07655
# Epoch 4/4
# 51200/51200 [==============================] - 14s 278us/step - loss: 84893.7043 - mean_absolute_error: 200.5300 - val_loss: 834482.7866 - val_mean_absolute_error: 750.9608
#
# Epoch 00004: val_loss did not improve from 702932.07655
# acc_with_2%: 0.1655 acc_with_5%: 0.397 RMSE: [489.5778]
# acc_with_2%: 0.1655 acc_with_5%: 0.397 RMSE: [489.5778]
# (0.1655, array([489.5778], dtype=float32))
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_428 (Dense)            (None, 256)               27648
# _________________________________________________________________
# dense_429 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_430 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_431 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_432 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_433 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_434 (Dense)            (None, 1)                 257
# =================================================================
# Total params: 356,865
# Trainable params: 356,865
# Non-trainable params: 0
# _________________________________________________________________
# Train on 51200 samples, validate on 12800 samples
# Epoch 1/4
# 51200/51200 [==============================] - 19s 371us/step - loss: 1097388.5137 - mean_absolute_error: 465.2711 - val_loss: 622363.5527 - val_mean_absolute_error: 629.1112
#
# Epoch 00001: val_loss improved from 702932.07655 to 622363.55266, saving model to Weights-001--622363.55266.hdf5
# Epoch 2/4
# 51200/51200 [==============================] - 15s 286us/step - loss: 116323.5419 - mean_absolute_error: 240.2178 - val_loss: 638804.1303 - val_mean_absolute_error: 638.8564
#
# Epoch 00002: val_loss did not improve from 622363.55266
# Epoch 3/4
# 51200/51200 [==============================] - 14s 283us/step - loss: 94937.3103 - mean_absolute_error: 213.4839 - val_loss: 589871.6172 - val_mean_absolute_error: 574.6573
#
# Epoch 00003: val_loss improved from 622363.55266 to 589871.61715, saving model to Weights-003--589871.61715.hdf5
# Epoch 4/4
# 51200/51200 [==============================] - 14s 273us/step - loss: 89104.1439 - mean_absolute_error: 205.9037 - val_loss: 545404.6887 - val_mean_absolute_error: 562.1383
#
# Epoch 00004: val_loss improved from 589871.61715 to 545404.68875, saving model to Weights-004--545404.68875.hdf5
# acc_with_2%: 0.1884375 acc_with_5%: 0.4111875 RMSE: [525.6726]
# acc_with_2%: 0.1884375 acc_with_5%: 0.4111875 RMSE: [525.6726]
# (0.1884375, array([525.6726], dtype=float32))
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_435 (Dense)            (None, 256)               27648
# _________________________________________________________________
# dense_436 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_437 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_438 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_439 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_440 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_441 (Dense)            (None, 1)                 257
# =================================================================
# Total params: 356,865
# Trainable params: 356,865
# Non-trainable params: 0
# _________________________________________________________________
# Train on 51200 samples, validate on 12800 samples
# Epoch 1/4
# 51200/51200 [==============================] - 19s 372us/step - loss: 1124914.9507 - mean_absolute_error: 468.2703 - val_loss: 809198.7426 - val_mean_absolute_error: 745.9310
#
# Epoch 00001: val_loss did not improve from 545404.68875
# Epoch 2/4
# 51200/51200 [==============================] - 15s 290us/step - loss: 114891.3764 - mean_absolute_error: 238.6620 - val_loss: 668937.1658 - val_mean_absolute_error: 687.6278
#
# Epoch 00002: val_loss did not improve from 545404.68875
# Epoch 3/4
# 51200/51200 [==============================] - 15s 284us/step - loss: 100558.6793 - mean_absolute_error: 215.8215 - val_loss: 687298.3402 - val_mean_absolute_error: 705.1608
#
# Epoch 00003: val_loss did not improve from 545404.68875
# Epoch 4/4
# 51200/51200 [==============================] - 15s 286us/step - loss: 90019.9111 - mean_absolute_error: 205.6691 - val_loss: 833697.1224 - val_mean_absolute_error: 770.4016
#
# Epoch 00004: val_loss did not improve from 545404.68875
# acc_with_2%: 0.145125 acc_with_5%: 0.336875 RMSE: [513.22363]
# acc_with_2%: 0.145125 acc_with_5%: 0.336875 RMSE: [513.22363]
# (0.145125, array([513.22363], dtype=float32))
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_442 (Dense)            (None, 256)               27648
# _________________________________________________________________
# dense_443 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_444 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_445 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_446 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_447 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_448 (Dense)            (None, 1)                 257
# =================================================================
# Total params: 356,865
# Trainable params: 356,865
# Non-trainable params: 0
# _________________________________________________________________
# Train on 51200 samples, validate on 12800 samples
# Epoch 1/4
# 51200/51200 [==============================] - 19s 372us/step - loss: 1061120.0010 - mean_absolute_error: 454.7893 - val_loss: 629239.0110 - val_mean_absolute_error: 543.1197
#
# Epoch 00001: val_loss did not improve from 545404.68875
# Epoch 2/4
# 51200/51200 [==============================] - 14s 278us/step - loss: 128983.7173 - mean_absolute_error: 243.1863 - val_loss: 783999.6335 - val_mean_absolute_error: 657.1356
#
# Epoch 00002: val_loss did not improve from 545404.68875
# Epoch 3/4
# 51200/51200 [==============================] - 14s 279us/step - loss: 96604.0620 - mean_absolute_error: 213.8732 - val_loss: 764841.4544 - val_mean_absolute_error: 624.6063
# Epoch 00003: val_loss did not improve from 545404.68875
# Epoch 4/4
# 51200/51200 [==============================] - 14s 275us/step - loss: 87517.2435 - mean_absolute_error: 201.6717 - val_loss: 691222.6773 - val_mean_absolute_error: 588.1039
#
# Epoch 00004: val_loss did not improve from 545404.68875
# acc_with_2%: 0.1655 acc_with_5%: 0.3724375 RMSE: [607.5632]
# acc_with_2%: 0.1655 acc_with_5%: 0.3724375 RMSE: [607.5632]
# (0.1655, array([607.5632], dtype=float32))
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_449 (Dense)            (None, 256)               27648
# _________________________________________________________________
# dense_450 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_451 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_452 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_453 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_454 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_455 (Dense)            (None, 1)                 257
# =================================================================
# Total params: 356,865
# Trainable params: 356,865
# Non-trainable params: 0
# _________________________________________________________________
# Train on 51200 samples, validate on 12800 samples
# Epoch 1/4
# 51200/51200 [==============================] - 19s 374us/step - loss: 1099549.4316 - mean_absolute_error: 468.1593 - val_loss: 548797.6074 - val_mean_absolute_error: 604.0573
#
# Epoch 00001: val_loss did not improve from 545404.68875
# Epoch 2/4
# 51200/51200 [==============================] - 14s 280us/step - loss: 117072.1094 - mean_absolute_error: 239.8776 - val_loss: 632770.1877 - val_mean_absolute_error: 663.1161
#
# Epoch 00002: val_loss did not improve from 545404.68875
# Epoch 3/4
# 51200/51200 [==============================] - 15s 284us/step - loss: 93119.0537 - mean_absolute_error: 212.5287 - val_loss: 621701.1129 - val_mean_absolute_error: 644.5892
#
# Epoch 00003: val_loss did not improve from 545404.68875
# Epoch 4/4
# 51200/51200 [==============================] - 15s 289us/step - loss: 82275.2141 - mean_absolute_error: 197.4755 - val_loss: 535412.9156 - val_mean_absolute_error: 609.0813
#
# Epoch 00004: val_loss improved from 545404.68875 to 535412.91559, saving model to Weights-004--535412.91559.hdf5
# acc_with_2%: 0.13475 acc_with_5%: 0.351 RMSE: [477.93387]
# acc_with_2%: 0.13475 acc_with_5%: 0.351 RMSE: [477.93387]
# (0.13475, array([477.93387], dtype=float32))
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_456 (Dense)            (None, 256)               27648
# _________________________________________________________________
# dense_457 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_458 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_459 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_460 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_461 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_462 (Dense)            (None, 1)                 257
# =================================================================
# Total params: 356,865
# Trainable params: 356,865
# Non-trainable params: 0
# _________________________________________________________________
# Train on 51200 samples, validate on 12800 samples
# Epoch 1/4
# 51200/51200 [==============================] - 19s 379us/step - loss: 1074019.3671 - mean_absolute_error: 467.0358 - val_loss: 691563.2329 - val_mean_absolute_error: 669.6582
#
# Epoch 00001: val_loss did not improve from 535412.91559
# Epoch 2/4
# 51200/51200 [==============================] - 15s 284us/step - loss: 116787.2153 - mean_absolute_error: 239.2225 - val_loss: 747074.6619 - val_mean_absolute_error: 713.1456
#
# Epoch 00002: val_loss did not improve from 535412.91559
# Epoch 3/4
# 51200/51200 [==============================] - 15s 284us/step - loss: 100630.5168 - mean_absolute_error: 219.7691 - val_loss: 781384.9241 - val_mean_absolute_error: 721.2249
#
# Epoch 00003: val_loss did not improve from 535412.91559
# Epoch 4/4
# 51200/51200 [==============================] - 15s 297us/step - loss: 87114.1004 - mean_absolute_error: 203.6976 - val_loss: 684584.4141 - val_mean_absolute_error: 684.8890
#
# Epoch 00004: val_loss did not improve from 535412.91559
# acc_with_2%: 0.153125 acc_with_5%: 0.3734375 RMSE: [484.91974]
# acc_with_2%: 0.153125 acc_with_5%: 0.3734375 RMSE: [484.91974]
# (0.153125, array([484.91974], dtype=float32))
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_463 (Dense)            (None, 256)               27648
# _________________________________________________________________
# dense_464 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_465 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_466 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_467 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_468 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_469 (Dense)            (None, 1)                 257
# =================================================================
# Total params: 356,865
# Trainable params: 356,865
# Non-trainable params: 0
# _________________________________________________________________
# Train on 51200 samples, validate on 12800 samples
# Epoch 1/4
# 51200/51200 [==============================] - 21s 415us/step - loss: 1258451.4358 - mean_absolute_error: 482.9135 - val_loss: 1116621.9796 - val_mean_absolute_error: 742.3846
#
# Epoch 00001: val_loss did not improve from 535412.91559
# Epoch 2/4
# 51200/51200 [==============================] - 15s 296us/step - loss: 137550.5651 - mean_absolute_error: 254.7951 - val_loss: 705974.0992 - val_mean_absolute_error: 700.0383
#
# Epoch 00002: val_loss did not improve from 535412.91559
# Epoch 3/4
# 51200/51200 [==============================] - 15s 298us/step - loss: 96796.2937 - mean_absolute_error: 214.0085 - val_loss: 818746.6126 - val_mean_absolute_error: 753.9749
#
# Epoch 00003: val_loss did not improve from 535412.91559
# Epoch 4/4
# 51200/51200 [==============================] - 15s 302us/step - loss: 85649.2631 - mean_absolute_error: 202.0886 - val_loss: 962189.3338 - val_mean_absolute_error: 794.0753
#
# Epoch 00004: val_loss did not improve from 535412.91559
# acc_with_2%: 0.1561875 acc_with_5%: 0.4015 RMSE: [473.0605]
# acc_with_2%: 0.1561875 acc_with_5%: 0.4015 RMSE: [473.0605]
# (0.1561875, array([473.0605], dtype=float32))

# %%
predictions = ensemble(model_list,test_data)
calc_acc_and_rmse(predictions,test_target)
# Out:
# acc_with_2%: 0.17498277050310132 acc_with_5%: 0.4573053066850448 RMSE: [559.63965]
# (0.17498277050310132, array([559.63965], dtype=float32))
